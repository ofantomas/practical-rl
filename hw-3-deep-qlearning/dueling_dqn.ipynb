# %%
import gym
import random
import numpy as np
import torch
import torch.nn as nn
import utils
import atari_wrappers
import matplotlib.pyplot as plt


from framebuffer import FrameBuffer
from experience_replay import ReplayBuffer

# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %%
seed = 228
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

# %%
ENV_NAME = "BreakoutNoFrameskip-v4"

env = atari_wrappers.make_env(env_name=ENV_NAME, h=84, w=84, seed=seed)
env.reset()
n_actions = env.action_space.n
state_shape = env.observation_space.shape

# %%
from models import DuelingDQNAgent
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

agent = DuelingDQNAgent(state_shape, n_actions, epsilon=1).to(device)
target_network = DuelingDQNAgent(agent.state_shape, agent.n_actions, epsilon=0).to(device)
target_network.load_state_dict(agent.state_dict())
# Out:
# <All keys matched successfully>

# %%
agent
# Out:
# DuelingDQNAgent(
#   (network): Sequential(
#     (conv_1): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (relu_1): ReLU()
#     (conv_2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (relu_2): ReLU()
#     (conv_3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (relu_3): ReLU()
#   )
#   (v): Sequential(
#     (linear_1): Linear(in_features=3136, out_features=512, bias=True)
#     (relu_linear): ReLU()
#     (linear_2): Linear(in_features=512, out_features=1, bias=True)
#   )
#   (adv): Sequential(
#     (linear_1): Linear(in_features=3136, out_features=512, bias=True)
#     (relu_linear): ReLU()
#     (linear_2): Linear(in_features=512, out_features=4, bias=True)
#   )
# )

# %%
from experience_replay import make_experience_replay

exp_replay = make_experience_replay(env, agent, init_size=3*10**4, size=10**5)

# %%
from losses import compute_td_loss_double_q
from train import train

history = train(env, agent, target_network, exp_replay, compute_td_loss_double_q, device, batch_size=32, total_steps=3 * 10**6, h=84, w=84)
# Out:
# buffer size = 100000, epsilon = 0.73450
# Mean reward: 2.7:  10%|▉         | 299997/3000001 [1:04:31<8:54:00, 84.27it/s]
# Stopping plotting to reduce training time.
# Mean reward: 11.3: 100%|██████████| 3000001/3000001 [10:18:24<00:00, 80.85it/s]

# %%
plt.figure(figsize=[16, 9])
plt.subplot(2, 2, 1)
plt.title("Mean reward per episode")
plt.plot(history['reward_history'])
plt.grid()

assert not np.isnan(history['td_loss_history'][-1])
plt.subplot(2, 2, 2)
plt.title("TD loss history (smoothened)")
plt.plot(utils.smoothen(history['td_loss_history']))
plt.grid()

plt.subplot(2, 2, 3)
plt.title("Initial state V")
plt.plot(history['initial_state_v_history'])
plt.grid()

plt.subplot(2, 2, 4)
plt.title("Grad norm history (smoothened)")
plt.plot(utils.smoothen(history['grad_norm_history']))
plt.grid()

plt.show()

# %%
torch.save(agent.state_dict(), "./models/dueling_dqn_bs_32_84x84.pth")

# %% [markdown]
# Final scoring is done on a whole episode with all 5 lives.

# %%
n_lives = 5

final_score = utils.evaluate(
              atari_wrappers.make_env(clip_rewards=False, h=84, w=84, seed=9),
    agent, n_games=30, greedy=True, t_max=10 * 1000
) * n_lives
print('final score:', final_score)
assert final_score > 10, 'not as cool as DQN can'
print('Cool!')
# Out:
# final score: 90.0
# Cool!

# %% [markdown]
# # Record a video

# %%
#agent.load_state_dict(torch.load("./models/dueling_dqn.pth"))

# %%
# record sessions
import gym.wrappers
env_monitor = gym.wrappers.Monitor(atari_wrappers.make_env(h=84, w=84), directory="videos/dueling_dqn/", force=True)
sessions = [utils.evaluate(env_monitor, agent, n_games=n_lives, greedy=True) for _ in range(10)]
env_monitor.close()
